# %%
import pandas as pd
import numpy as np
print("Hello")
# Out:
# Hello

# %%
data=pd.read_csv("popup_data.csv")

# %%
data.head(10)
# Out:
#                                Column1                           Column2  \
# 0                         College Name  Arya Girls College, Ambala Cantt
# 1                             District                            Ambala
# 2                       Education Mode                             Girls
# 3                          Contact No.                        1712640556
# 4                       Principal Name                   Dr. Anupma Arya
# 5     Nodal Officer (Online Admission)               Mrs Amandeep Makkar
# 6           Co-ordinator (Arts Stream)                     Dr Suman Bala
# 7       Co-ordinator (Commerce Stream)                      Dr Anju Bala
# 8        Co-ordinator (Science Stream)                               NaN
# 9  Co-ordinator (Job-Oriented Courses)                     Dr Rekha Rani
#
#                  Column3                      Column4
# 0           College Type     Government Aided College
# 1        College Address                52 Staff Road
# ...

# %%
import pandas as pd

# Load the data from a CSV file
data = pd.read_csv('popup_data.csv')

# Convert the DataFrame to markdown format
markdown = '| ' ' '.join(data.columns) + '\n'
markdown += '| ' ' '.join(['---'] * len(data.columns)) + '\n'
for index, row in data.iterrows():
    markdown += '| ' ' '.join(str(x) for x in row) + '\n'

# Print the markdown table
print(markdown)
# Out:
# Column1|  Column2|  Column3|  Column4
# ---|  ---|  ---|  ---
# College Name|  Arya Girls College, Ambala Cantt|  College Type|  Government Aided College
# District|  Ambala|  College Address|  52 Staff Road
# Education Mode|  Girls|  Website URL|  www.aryagirlscollegeamb.org
# Contact No.|  1712640556|  Email ID|  agcambalacantt@gmail.com
# Principal Name|  Dr. Anupma Arya|  Principal Contact No.|  9416393980
# Nodal Officer (Online Admission)|  Mrs Amandeep Makkar|  Contact No.|  9355573072
# Co-ordinator (Arts Stream)|  Dr Suman Bala|  Contact No.|  9416911618
# Co-ordinator (Commerce Stream)|  Dr Anju Bala|  Contact No.|  9416327518
# Co-ordinator (Science Stream)|  nan|  Contact No.|  nan
# Co-ordinator (Job-Oriented Courses)|  Dr Rekha Rani|  Contact No.|  9416687807
# Co-ordinator (Fee Structure)|  Mrs. Kamlesh Goel|  Contact No.|  7015982158
# nan|  nan|  nan|  nan
# ...

# %%
with open('output.md', 'w') as f:
    f.write(markdown)

# %%
import pandas as pd

# Load the data from a CSV file
data = pd.read_csv('popup_data.csv')

# Convert the DataFrame to markdown format
markdown = data.to_markdown(index=False)

# Print the markdown table
print(markdown)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
with open('output.md', 'w') as f:
    f.write(markdown)

# %%
df.to_excel('Final_College_data.xlsx', index=False)
